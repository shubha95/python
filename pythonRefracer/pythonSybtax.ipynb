# %%
# identifier
x  = 10

# x is a indentifier
# 4 spaces are a tab make code in a modular without use of bracket {}
#

# %% [markdown]
# Input and outpu

# %%
# input for user -> input() function is used to take input from user

input1 = input("Enter your name: ")

print("Hello", input1)
# Out:
# Hello shubham

# %% [markdown]
# # list
#  1 Variables
#  2 naming convence
#  3 Data Type
#    Integer
#    Float
#    Boolean
#    Strings
