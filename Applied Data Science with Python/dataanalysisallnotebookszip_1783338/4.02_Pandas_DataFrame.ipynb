# %% [markdown]
# # __Pandas DataFrame__

# %% [markdown]
# ## __Agenda__
#
# - Introduction to Pandas DataFrame
#   * Creating a DataFrame Using Different Methods
#   * Accessing the DataFrame
#   * Understanding DataFrame Basics
# - Introduction to Statistical Operations in Pandas
#   * Descriptive Statistics
#   * Mean, Median, and Standard Deviation
#   * Correlation Analysis

# %% [markdown]
# ## __1. Introduction to Pandas DataFrame__

# %% [markdown]
# A Pandas DataFrame is a two-dimensional, tabular data structure with labeled axes (rows and columns).
#
# It is a primary data structure in the Pandas library, providing a versatile and efficient way to handle and manipulate data in Python.
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_04_Working_with_Pandas/2_Introduction_to_DataFrame/Introduction_to_Pandas_DataFrame.png)

# %% [markdown]
# ### __Key Features:__
# - __Tabular structure:__ The DataFrame is organized as a table with rows and columns, similar to a spreadsheet or SQL table.
#
# - __Labeled axes:__ Both rows and columns are labeled, allowing for easy indexing and referencing of data.
#
# - __Heterogeneous data types:__ Each column in a DataFrame can contain different types of data, such as integers, floats, strings, or even complex objects.
#
# - __Versatility:__ DataFrames can store and handle a wide range of data formats, including CSV, Excel, SQL databases, and more.
#
# - __Data alignment:__ Operations on DataFrames are designed to handle missing values gracefully, aligning data based on labels.

# %% [markdown]
# ### __1.1 Creating a DataFrame Using Different Methods__
# Creating a Pandas DataFrame is a fundamental step in data analysis and manipulation.
# - Diverse methods are available within Pandas to generate a DataFrame, addressing various data sources and structures.
# - Data, whether in Python dictionaries, lists, NumPy arrays, or external files such as CSV and Excel, can be seamlessly transformed into a structured tabular format by Pandas.

# %%
import pandas as pd

# Creating a DataFrame from a dictionary
data_dict = {'Name': ['Alice', 'Bob', 'Charlie'],
             'Age': [25, 30, 22],
             'Salary': [50000, 60000, 45000]}

df_dict = pd.DataFrame(data_dict)
print(df_dict)

# Creating a DataFrame from lists
data_list = [['Alice', 25, 50000], ['Bob', 30, 60000], ['Charlie', 22, 45000]]

# Defining column names
columns = ['Name', 'Age', 'Salary']

df_list = pd.DataFrame(data_list, columns=columns)
print(df_list)

# Creating a DataFrame from a NumPy array
import numpy as np
data_array = np.array([['Alice', 25, 50000],
                       ['Bob', 30, 60000],
                       ['Charlie', 22, 45000]])

df_array = pd.DataFrame(data_array, columns=columns)
print(df_array)

# Creating a DataFrame from a CSV file
df_csv = pd.read_csv('/content/Lesson_04_Working_With_Pandas/Dataset/HousePrices.csv')
print(df_csv)

# Creating a DataFrame from an Excel file
df_excel = pd.read_excel('/content/Lesson_04_Working_With_Pandas/Dataset/Iris.xlsx')
print(df_excel)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   22   45000
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   22   45000
#       Name Age Salary
# 0    Alice  25  50000
# 1      Bob  30  60000
# 2  Charlie  22  45000
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Datasets/Leads.csv')
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# 0                            0                   0.0  ...
# 1                          674                   2.5  ...
# 2                         1532                   2.0  ...
# 3                          305                   1.0  ...
# 4                         1428                   1.0  ...
#
#   Get updates on DM Content    Lead Profile    City  \
# 0                        No          Select  Select
# 1                        No          Select  Select
# 2                        No  Potential Lead  Mumbai
# 3                        No          Select  Mumbai
# 4                        No          Select  Mumbai
#
#   Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0                   02.Medium                  02.Medium
# 1                   02.Medium                  02.Medium
# 2                   02.Medium                    01.High
# 3                   02.Medium                    01.High
# 4                   02.Medium                    01.High
#
#   Asymmetrique Activity Score Asymmetrique Profile Score  \
# 0                        15.0                       15.0
# 1                        15.0                       15.0
# 2                        14.0                       20.0
# 3                        13.0                       17.0
# 4                        15.0                       18.0
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified
#
# [5 rows x 37 columns]

# %% [markdown]
# ### __1.2 Accessing the DataFrame__
#
# Accessing a Pandas DataFrame involves employing various methods for selecting and retrieving data, whether it be specific columns, rows, or individual cells.
# - Utilizing square brackets, iloc and loc indexers, and conditions, analysts can navigate and extract the necessary information from the DataFrame for further analysis and manipulation.
# - The flexibility of Pandas allows for both label-based and position-based indexing, offering a versatile toolkit for accessing and working with data efficiently.

# %%
import pandas as pd

# Creating a sample DataFrame
data = {'Column_name': [5, 15, 8],
        'Column1': [10, 20, 30],
        'Column2': [100, 200, 300],
        'Another_column': [25, 35, 45]}

df = pd.DataFrame(data)

# Accessing a single column
column_data = df['Column_name']
print("Single column:")
print(column_data)

# Accessing multiple columns
selected_columns = df[['Column1', 'Column2']]
print("\nMultiple columns:")
print(selected_columns)

# Accessing a specific row by index
row_data = df.iloc[0]
print("\nSpecific row:")
print(row_data)

# Accessing rows based on a condition
filtered_rows = df[df['Column_name'] > 10]
print("\nFiltered rows:")
print(filtered_rows)

# Accessing a single cell by label
value = df.at[0, 'Column_name']
print("\nSingle cell by label:")
print(value)

# Accessing a single cell by position
value = df.iat[0, 1]  # Row 0, Column 1
print("\nSingle cell by position:")
print(value)

# Accessing data using .loc
selected_data = df.loc[0, 'Column_name']
print("\nData using .loc:")
print(selected_data)

# Conditional access
selected_data = df[df['Column_name'] > 10]['Another_column']
print("\nConditional access:")
print(selected_data)
# Out:
# Single column:
# 0     5
# 1    15
# 2     8
# Name: Column_name, dtype: int64
#
# Multiple columns:
#    Column1  Column2
# 0       10      100
# 1       20      200
# 2       30      300
#
# Specific row:
# Column_name         5
# Column1            10
# Column2           100
# Another_column     25
# Name: 0, dtype: int64
#
# Filtered rows:
#    Column_name  Column1  Column2  Another_column
# 1           15       20      200              35
#
# Single cell by label:
# 5
#
# Single cell by position:
# 10
#
# Data using .loc:
# 5
#
# Conditional access:
# 1    35
# Name: Another_column, dtype: int64

# %% [markdown]
# ### __1.3 Understanding DataFrame Basics__
# - The head() and tail() methods enable users to efficiently preview the initial and final rows of a DataFrame, offering a quick snapshot of its structure and content.
# - These functions are invaluable for a preliminary assessment of column names, data types, and potential issues. Additionally, the info() method provides a comprehensive summary, detailing data types, non-null counts, and memory usage, aiding in the identification of missing or inconsistent data.
# - The shape attribute, on the other hand, succinctly communicates the dimensions of the DataFrame, encapsulating the number of rows and columns.
# - The syntax for some functions is provided below:

# %% [markdown]
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_04_Working_with_Pandas/2_Introduction_to_DataFrame/Understanding_DataFrame_Basics.png)

# %%
import pandas as pd

# Create a sample DataFrame
data = {'Column_name': [5, 15, 8],
        'Column1': [10, 20, 30],
        'Column2': [100, 200, 300],
        'Another_column': [25, 35, 45]}

df = pd.DataFrame(data)

# Display the first 2 rows
print("First 2 rows:")
print(df.head(2))

# Display the last row
print("\nLast row:")
print(df.tail(1))

# Provide a comprehensive summary of the DataFrame
print("\nDataFrame summary:")
df.info()

# Return a tuple representing the dimensions of the DataFrame (Rows, columns)
print("\nDataFrame dimensions:")
print(df.shape)
# Out:
# First 2 rows:
#    Column_name  Column1  Column2  Another_column
# 0            5       10      100              25
# 1           15       20      200              35
#
# Last row:
#    Column_name  Column1  Column2  Another_column
# 2            8       30      300              45
#
# DataFrame summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Column_name     3 non-null      int64
#  1   Column1         3 non-null      int64
#  2   Column2         3 non-null      int64
#  3   Another_column  3 non-null      int64
# dtypes: int64(4)
# memory usage: 224.0 bytes
#
# DataFrame dimensions:
# (3, 4)

# %% [markdown]
# ## __2. Introduction to Statistical Operations in Pandas__
# Pandas supports the computation of fundamental measures such as mean and median, along with the exploration of correlations and distribution characteristics.
#
# The following examples illustrate key statistical operations available in Pandas:

# %% [markdown]
# ### __2.1 Descriptive Statistics__
# It offers a snapshot of the dataset's central tendencies and dispersions.
#
# The describe() function provides a quick summary, including mean, standard deviation, and quartile information.

# %%
import pandas as pd

# Create a sample DataFrame with numeric columns
data = {'Numeric_column1': [5, 15, 8],
        'Numeric_column2': [10, 20, 30],
        'Numeric_column3': [100, 200, 300]}

df = pd.DataFrame(data)

# Display descriptive statistics for numeric columns
print("Descriptive statistics for numeric columns:")
print(df.describe())
# Out:
# Descriptive statistics for numeric columns:
#        Numeric_column1  Numeric_column2  Numeric_column3
# count         3.000000              3.0              3.0
# mean          9.333333             20.0            200.0
# std           5.131601             10.0            100.0
# min           5.000000             10.0            100.0
# 25%           6.500000             15.0            150.0
# 50%           8.000000             20.0            200.0
# 75%          11.500000             25.0            250.0
# max          15.000000             30.0            300.0

# %% [markdown]
# ### __2.1 Mean, Median, and Standard Deviation__

# %%
import pandas as pd

# Create a sample DataFrame with numeric columns
data = {'Numeric_column1': [5, 15, 8],
        'Numeric_column2': [10, 20, 30],
        'Numeric_column3': [100, 200, 300]}

df = pd.DataFrame(data)

# Calculate mean, median, and standard deviation
mean_value = df.mean()
median_value = df.median()
std_deviation = df.std()

print("Mean:\n", mean_value)
print("\nMedian:\n", median_value)
print("\nStandard deviation:\n", std_deviation)
# Out:
# Mean:
#  Numeric_column1      9.333333
# Numeric_column2     20.000000
# Numeric_column3    200.000000
# dtype: float64
#
# Median:
#  Numeric_column1      8.0
# Numeric_column2     20.0
# Numeric_column3    200.0
# dtype: float64
#
# Standard deviation:
#  Numeric_column1      5.131601
# Numeric_column2     10.000000
# Numeric_column3    100.000000
# dtype: float64

# %% [markdown]
# ### __2.2 Correlation Analysis__
# The corr() function generates a correlation matrix, indicating how variables relate to each other.
#
# Values closer to 1 or -1 imply a stronger correlation, while values near 0 suggest a weaker correlation.

# %%
import pandas as pd

# Create a sample DataFrame with numeric columns
data = {'Numeric_column1': [5, 15, 8],
        'Numeric_column2': [10, 20, 30],
        'Numeric_column3': [100, 200, 300]}

df = pd.DataFrame(data)

# Compute correlation matrix
correlation_matrix = df.corr()

print("Correlation matrix:\n", correlation_matrix)
# Out:
# Correlation matrix:
#                   Numeric_column1  Numeric_column2  Numeric_column3
# Numeric_column1         1.000000         0.292306         0.292306
# Numeric_column2         0.292306         1.000000         1.000000
# Numeric_column3         0.292306         1.000000         1.000000

# %% [markdown]
# #### __Value Counts__
# The value_counts() function tallies the occurrences of unique values in a categorical column, aiding in understanding the distribution of categorical data.

# %%
import pandas as pd

# Create a sample DataFrame with a category column
data = {'Category': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'A', 'B', 'C']}
df = pd.DataFrame(data)

# Count occurrences of unique values in the category column
value_counts = df['Category'].value_counts()

print("Value counts:\n", value_counts)
# Out:
# Value counts:
#  Category
# A    4
# B    3
# C    3
# Name: count, dtype: int64

# %% [markdown]
# # __Assisted Practice__

# %% [markdown]
# ## __Problem Statement:__
# Analyze a housing dataset using Pandas DataFrame and statistical operations to understand the basic characteristics of the data and the relationships between different variables.

# %% [markdown]
# ## __Steps to Perform:__
# - Load the housing dataset into a Pandas DataFrame
# - Familiarize with the DataFrame basics such as its structure, data types of the columns, and summary statistics
# - Calculate descriptive statistics like mean, median, and standard deviation for numerical columns such as __LotArea__, __YearBuilt__, __1stFlrSF__, __2ndFlrSF__, and __SalePrice__
# - Determine the correlation between different numerical variables such as __LotArea__ and __SalePrice__, __YearBuilt__ and __SalePrice__, __1stFlrSF__ and __SalePrice__, and __2ndFlrSF__ and __SalePrice__
# - Count the number of occurrences of each category in categorical variables such as __Neighborhood__, __BldgType__, and __HouseStyle__

# %%
# unzip Dataset.zip
# !unzip '/content/Dataset.zip'
# Out:
# Archive:  /content/Dataset.zip
#    creating: Lesson 11_Data_Wrangling/
#    creating: Lesson 11_Data_Wrangling/11.02_Pandorable_or_Idiomatic_Pandas_Code/
#   inflating: Lesson 11_Data_Wrangling/11.02_Pandorable_or_Idiomatic_Pandas_Code/HousePrices.csv
#    creating: Lesson 11_Data_Wrangling/11.03_Loading_Indexing_and_Reindexing/
#   inflating: Lesson 11_Data_Wrangling/11.03_Loading_Indexing_and_Reindexing/HousePrices.csv
#    creating: Lesson 11_Data_Wrangling/11.04_Merging/
#   inflating: Lesson 11_Data_Wrangling/11.04_Merging/Merge1.csv
#   inflating: Lesson 11_Data_Wrangling/11.04_Merging/Merge2.csv
#    creating: Lesson 11_Data_Wrangling/11.05_Memory_Optimization_in_Python/
#   inflating: Lesson 11_Data_Wrangling/11.05_Memory_Optimization_in_Python/HousePrices.csv
#    creating: Lesson 11_Data_Wrangling/11.08_Data_Binning_Formatting_and_Normalization/
#   inflating: Lesson 11_Data_Wrangling/11.08_Data_Binning_Formatting_and_Normalization/CarPrices.csv
#    creating: Lesson 11_Data_Wrangling/11.09_Data_Binning_Standardization/
#   inflating: Lesson 11_Data_Wrangling/11.09_Data_Binning_Standardization/HousePrices.csv
#    creating: Lesson 11_Data_Wrangling/11.10_Describing_Data/
#   inflating: Lesson 11_Data_Wrangling/11.10_Describing_Data/HousePrices.csv
#    creating: Lesson 12_Data_Visualization/
#    creating: Lesson 12_Data_Visualization/12.03_Visualizing_Data_Using_Pivot_Tables/
#   inflating: Lesson 12_Data_Visualization/12.03_Visualizing_Data_Using_Pivot_Tables/HousePrices.csv
#    creating: Lesson 12_Data_Visualization/12.12_Introduction_to_Matplotlib/
#   inflating: Lesson 12_Data_Visualization/12.12_Introduction_to_Matplotlib/HousePrices.csv
#    creating: Lesson 12_Data_Visualization/12.13_Matplotlib_for_3D_Visualization/
#   inflating: Lesson 12_Data_Visualization/12.13_Matplotlib_for_3D_Visualization/ADANIPORTS.csv
#    creating: Lesson 12_Data_Visualization/12.14_Using_Matplotlib_with_Other_Python_Packages/
#   inflating: Lesson 12_Data_Visualization/12.14_Using_Matplotlib_with_Other_Python_Packages/Sample.txt
#    creating: Lesson 12_Data_Visualization/12.17_Plotting_3D_Graphs_for_Multiple_Columns_Using_Seaborn/
#   inflating: Lesson 12_Data_Visualization/12.17_Plotting_3D_Graphs_for_Multiple_Columns_Using_Seaborn/ADANIPORTS.csv
#    creating: Lesson 12_Data_Visualization/12.18_Introduction_to_Plotly/
#   inflating: Lesson 12_Data_Visualization/12.18_Introduction_to_Plotly/HousePrices.csv
#    creating: Lesson 12_Data_Visualization/12.19_Introduction_to_Bokeh/
#   inflating: Lesson 12_Data_Visualization/12.19_Introduction_to_Bokeh/HousePrices.csv
#    creating: Lesson_04_Working_With_Pandas/
#    creating: Lesson_04_Working_With_Pandas/Assisted_Practice_Dataset/
#   inflating: Lesson_04_Working_With_Pandas/Assisted_Practice_Dataset/HousePrices.csv
#   inflating: Lesson_04_Working_With_Pandas/Assisted_Practice_Dataset/housing_data.csv
#   inflating: Lesson_04_Working_With_Pandas/Assisted_Practice_Dataset/Weather_data.csv
#    creating: Lesson_04_Working_With_Pandas/Dataset/
#   inflating: Lesson_04_Working_With_Pandas/Dataset/HousePrices.csv
#   inflating: Lesson_04_Working_With_Pandas/Dataset/housing_data.csv
#   inflating: Lesson_04_Working_With_Pandas/Dataset/Iris.xlsx
#    creating: Lesson_05_Data_Visualization/
#    creating: Lesson_05_Data_Visualization/Assisted_Practice_Dataset/
#   inflating: Lesson_05_Data_Visualization/Assisted_Practice_Dataset/HousePrices.csv
#   inflating: Lesson_05_Data_Visualization/Assisted_Practice_Dataset/housing_data.csv
#    creating: Lesson_05_Data_Visualization/Dataset/
#   inflating: Lesson_05_Data_Visualization/Dataset/ADANIPORTS.csv
#    creating: Lesson_07_Probability_Distribution/
#    creating: Lesson_07_Probability_Distribution/Assisted Practice Dataset/
#   inflating: Lesson_07_Probability_Distribution/Assisted Practice Dataset/Retail_Store_Data.csv
#    creating: Lesson_08_Advanced_Statistics/
#    creating: Lesson_08_Advanced_Statistics/Assisted Practice Dataset/
#   inflating: Lesson_08_Advanced_Statistics/Assisted Practice Dataset/cutlets.csv
#    creating: Lesson_08_Advanced_Statistics/Dataset/
#   inflating: Lesson_08_Advanced_Statistics/Dataset/Ages.csv
#   inflating: Lesson_08_Advanced_Statistics/Dataset/blood_pressure.csv
#   inflating: Lesson_08_Advanced_Statistics/Dataset/chi-test.csv
#   inflating: Lesson_08_Advanced_Statistics/Dataset/crop_yield.csv
#   inflating: Lesson_08_Advanced_Statistics/Dataset/Customer+OrderForm.csv
#   inflating: Lesson_08_Advanced_Statistics/Dataset/employee_satisfaction.csv
#   inflating: Lesson_08_Advanced_Statistics/Dataset/plant.csv
#    creating: Lesson_09_Data_Wrangling/
#    creating: Lesson_09_Data_Wrangling/Assisted_Practice_Dataset/
#   inflating: Lesson_09_Data_Wrangling/Assisted_Practice_Dataset/HousePrices.csv
#   inflating: Lesson_09_Data_Wrangling/Assisted_Practice_Dataset/housing_data.csv
#    creating: Lesson_10_Feature_Engineering/
#    creating: Lesson_10_Feature_Engineering/Assisted_Ptactice_Dataset/
#   inflating: Lesson_10_Feature_Engineering/Assisted_Ptactice_Dataset/Iris.csv
#    creating: Lesson_10_Feature_Engineering/Dataset/
#   inflating: Lesson_10_Feature_Engineering/Dataset/HousePrices.csv
#   inflating: Lesson_10_Feature_Engineering/Dataset/housing_data.csv
#    creating: Lesson_13_End_to_End_Statistics_Application_with_Python/
#    creating: Lesson_13_End_to_End_Statistics_Application_with_Python/13.02_Basic_Statistics_with_Python_Problem_Statment/
#   inflating: Lesson_13_End_to_End_Statistics_Application_with_Python/13.02_Basic_Statistics_with_Python_Problem_Statment/pivot.csv
#    creating: Lesson_13_End_to_End_Statistics_Application_with_Python/13.03_Basic_Statistics_with_Python_Solution/
#   inflating: Lesson_13_End_to_End_Statistics_Application_with_Python/13.03_Basic_Statistics_with_Python_Solution/pivot.csv

# %% [markdown]
# ## Step 1: Data Ingestion / Data Loading

# %%
import pandas as pd


path = '/content/Lesson_04_Working_With_Pandas/Dataset/HousePrices.csv'

# create df with reading the external file
data = pd.read_csv(path)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = pd.read_excel('/content/Lesson_04_Working_With_Pandas/Dataset/Iris.xlsx')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# plot
df.sepal_length.plot()
# Out:
# <Axes: >

# %%
# opening a excelfile - pass the openpyxl engine

# !pip install openpyxl
df = pd.read_excel('/content/Lesson_04_Working_With_Pandas/Dataset/Iris.xlsx', engine='openpyxl')
df.head()
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
## read a json file
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abelgeorge2222/collected-works-mahatma-gandhi-a-json-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/abelgeorge2222/collected-works-mahatma-gandhi-a-json-dataset/8.archive...
# 100%|██████████| 32.3M/32.3M [00:00<00:00, 162MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/abelgeorge2222/collected-works-mahatma-gandhi-a-json-dataset/versions/8

# %%
# copy the content from path to content

# !cp -r '/root/.cache/kagglehub/datasets/abelgeorge2222/collected-works-mahatma-gandhi-a-json-dataset/versions/8' '/content/Lesson_04_Working_With_Pandas/Dataset'

# %%
# json file loading to pandas
df = pd.read_json('/content/Lesson_04_Working_With_Pandas/Dataset/8/The-Collected-Works-Mahatma-Gandhi.json')
df.head()
# Out:
#    volume  section document_type document_date  \
# 0       1        1         PROSE          1884
# 1       1        2    TRANSCRIPT    04-07-1888
# 2       1        3        LETTER    09-11-1888
# 3       1        4         PROSE    12-11-1888
# 4       1        5        LETTER       12-1888
#
#                                   title  \
# 0                          A CONFESSION
# 1  SPEECH AT ALFRED HIGH SCHOOL, RAJKOT
# 2           LETTER TO LAKSHMIDAS GANDHI
# 3                          LONDON DIARY
# 4     DRAFT OF LETTER TO FREDERICK LELY
#
#                                             contents  \
# 0  {1} I wrote it on a slip of paper and handed i...
# 1  {1} July 4, 1888 I hope that some of you will ...
# 2  LONDON, Friday, November 9, 1888 RESPECTED BRO...
# 3  {1} LONDON, November, 12 1888 What led to the ...
# 4  {1} LONDON, December, 1888 DEAR SIR, You will ...
#
#                                            footnotes original_language  \
# 0  {'1': 'When Gandhiji was 15, he had removed a ...           English
# 1  {'1': 'Gandhiji was given a send-off by his fe...          Gujarati
# 2                                                 {}           English
# 3  {'1': 'When his nephew and co-worker, Chhaganl...           English
# 4  {'1': 'Gandhiji sent this to his elder brother...           English
#
#                                               source
# 0                  An Autobiography, Pt. I, Ch. VIII
# 1                         Kethiawar Times, 12-7-1888
# 2  Mahatma, Vol. I; also from a photostat of the ...
# 3
# 4             Mahatma, Vol. I; also from a photostat

# %%
# !pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("juanschafle/cyber-attack-detection-using-network-traffic")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'cyber-attack-detection-using-network-traffic' dataset.
# Path to dataset files: /kaggle/input/cyber-attack-detection-using-network-traffic

# %%
df = pd.read_csv('/kaggle/input/cyber-attack-detection-using-network-traffic/cyber_attack_dataset_100000.csv')
df.head()
# Out:
#    duration  src_bytes  dst_bytes  packet_count protocol  failed_logins  \
# 0         1       8605        418           631      TCP              0
# 1         1        499        148           131      UDP              0
# 2        10        370        160           105      UDP              0
# 3         2       5138        320           666      TCP              0
# 4        36        524        467            58      UDP             10
#
#   attack_type
# 0        DDoS
# 1    PortScan
# 2    PortScan
# 3        DDoS
# 4  BruteForce

# %%
import sqlite3
