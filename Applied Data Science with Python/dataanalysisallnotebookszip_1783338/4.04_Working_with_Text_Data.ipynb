# %% [markdown]
# # __Working with Text Data in Pandas__
#
# ## __Agenda__
#
# - Text Data in Pandas
# - Iteration
#   * Iterating over Rows
#   * Applying a Function to Each Element
#   * Vectorized Operations
#   * Iterating over Series
# - Sorting
#   * Sorting DataFrame by Column
#   * Sorting DataFrame by Multiple Columns
#   * Sorting DataFrame by Index
#   * Sorting a Series
# - Plotting with Pandas

# %% [markdown]
# ### __1. Text Data in Pandas__
#
# Working with text data in Pandas involves various operations to manipulate and analyze textual information. Here are some common text data operations using Pandas:

# %%
import pandas as pd
import seaborn as sns
# load the titnaic dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Assuming 'df' is DataFrame with a 'Column' containing text data
import pandas as pd

df = pd.DataFrame({'Column': ['Hello', 'World', 'Python', 'Data Science']})

# Calculates the length of each string
df['Length'] = df['Column'].str.len()
print("Length of each string:")
print(df[['Column', 'Length']])
# Out:
# Length of each string:
#          Column  Length
# 0         Hello       5
# 1         World       5
# 2        Python       6
# 3  Data Science      12

# %%
# Assuming 'df' is DataFrame with a 'Column' containing text data
df = pd.DataFrame({'Column': ['Hello', 'World', 'Python', 'Data Science']})

# Converts text to lowercase
df['Lowercase'] = df['Column'].str.lower()
print("\nText in lowercase:")
print(df[['Column', 'Lowercase']])
# Out:
# Text in lowercase:
#          Column     Lowercase
# 0         Hello         hello
# 1         World         world
# 2        Python        python
# 3  Data Science  data science

# %%
# Assuming 'df' is DataFrame with a 'Column' containing text data
df = pd.DataFrame({'Column': ['Hello', 'World', 'Python', 'Data Science']})

# Checks if each string contains the specified substring
substring = 'Data'
df['ContainsSubstring'] = df['Column'].str.contains(substring)
print("\nContains substring 'Data':")
print(df[['Column', 'ContainsSubstring']])
# Out:
# Contains substring 'Data':
#          Column  ContainsSubstring
# 0         Hello              False
# 1         World              False
# 2        Python              False
# 3  Data Science               True

# %% [markdown]
# ## __2. Iteration__

# %% [markdown]
# Iteration in Pandas typically involves traversing through the rows or elements of a DataFrame or Series.
# - However, it is important to note that direct iteration over DataFrame rows using Python's for loop is generally discouraged due to performance reasons.
# - Instead, Pandas provides efficient methods for iteration and applying functions to DataFrame elements.

# %% [markdown]
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Lesson_04_Working_with_Pandas/4_Working_with_Text_Data_in_Pandas/Iteration.png)

# %% [markdown]
# ### __2.1 Iterating over Rows__

# %%
import pandas as pd

# Assuming 'df' is your DataFrame with columns 'Column1' and 'Column2'
df = pd.DataFrame({'Column1': [1, 2, 3], 'Column2': ['A', 'B', 'C']})

for index, row in df.iterrows():
    print(f"Index: {index}, Data: {row['Column1']}, {row['Column2']}")
# Out:
# Index: 0, Data: 1, A
# Index: 1, Data: 2, B
# Index: 2, Data: 3, C

# %%
df.head()
# Out:
#    Column1 Column2
# 0        1       A
# 1        2       B
# 2        3       C

# %% [markdown]
# ### __2.2 Applying a Function to Each Element__

# %%
# Assuming 'df' is your DataFrame with 'ExistingColumn'
df = pd.DataFrame({'ExistingColumn': [10, 20, 30]})

df['NewColumn'] = df['ExistingColumn'].apply(lambda x: x * 2)
print(df)
# Out:
#    ExistingColumn  NewColumn
# 0              10         20
# 1              20         40
# 2              30         60

# %% [markdown]
# ### __2.3 Vectorized Operations__

# %%
# Assuming 'df' is your DataFrame with 'ColumnA' and 'ColumnB'
df = pd.DataFrame({'ColumnA': [1, 2, 3], 'ColumnB': [4, 5, 6]})

df['ResultColumn'] = df['ColumnA'] + df['ColumnB']
print(df)
# Out:
#    ColumnA  ColumnB  ResultColumn
# 0        1        4             5
# 1        2        5             7
# 2        3        6             9

# %% [markdown]
# ### __2.4 Iterating over Series__

# %%
# Assuming 'series' is your Pandas Series
series = pd.Series([10, 20, 30], name='Values')

for index, value in series.items():
    print(f"Index: {index}, Value: {value}")
# Out:
# Index: 0, Value: 10
# Index: 1, Value: 20
# Index: 2, Value: 30

# %% [markdown]
# ## __3. Sorting__
# Sorting in Pandas involves arranging the elements of a DataFrame or Series based on specific criteria, such as column values or indices.
#
# ![link text](https://labcontent.simplicdn.net/data-content/content-assets/Data_and_AI/ADSP_Images/Updated_Images/Lesson_4/4_04/Sorting.png)

# %% [markdown]
# ### __3.1 Sorting DataFrame by Column__

# %%
# Create a sample DataFrame
df = pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie'],
                   'Age': [25, 22, 30],
                   'Salary': [50000, 60000, 75000]})

# Sort DataFrame by the 'Age' column in ascending order
df_sorted = df.sort_values(by='Age')
print("Sorted DataFrame by Age:\n", df_sorted)
# Out:
# Sorted DataFrame by Age:
#        Name  Age  Salary
# 1      Bob   22   60000
# 0    Alice   25   50000
# 2  Charlie   30   75000

# %% [markdown]
# ### __3.2 Sorting DataFrame by Multiple Columns__

# %%
# Sort DataFrame by 'Age' in ascending order, then by 'Salary' in descending order
df_sorted_multi = df.sort_values(by=['Age', 'Salary'], ascending=[True, False])
print("\nSorted DataFrame by Age and Salary:\n", df_sorted_multi)
# Out:
# Sorted DataFrame by Age and Salary:
#        Name  Age  Salary
# 1      Bob   22   60000
# 0    Alice   25   50000
# 2  Charlie   30   75000

# %% [markdown]
# ### __3.3 Sorting DataFrame by Index__

# %%
# Sort DataFrame by index in descending order
df_sorted_index = df.sort_index(ascending=False)
print("\nSorted DataFrame by Index:\n", df_sorted_index)
# Out:
# Sorted DataFrame by Index:
#        Name  Age  Salary
# 2  Charlie   30   75000
# 1      Bob   22   60000
# 0    Alice   25   50000

# %% [markdown]
# ### __3.4 Sorting a Series__

# %%
# Create a sample Series
series = pd.Series([25, 22, 30], index=['Alice', 'Bob', 'Charlie'], name='Age')

# Sort Series in descending order
series_sorted = series.sort_values(ascending=False)
print("\nSorted Series by Age:\n", series_sorted)
# Out:
# Sorted Series by Age:
#  Charlie    30
# Alice      25
# Bob        22
# Name: Age, dtype: int64

# %% [markdown]
# ## __4. Plotting with Pandas__
# Plotting data is required to visualize the data in Python. Python uses the plot method in pandas to create plots; there are many types of plots available in pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a sample DataFrame
data = {'A': [1, 2, 3, 4, 5], 'B': [5, 4, 3, 2, 1]}
df = pd.DataFrame(data)

# Plot a line chart
df.plot()
plt.show()

# %%
# Plot a bar chart
df.plot(kind='bar')
plt.show()

# %% [markdown]
# # __Assisted Practice__

# %% [markdown]
# ## __Problem Statement:__
# Create a detailed report on the monthly weather data by performing text manipulation, data sorting, and visualization to analyze temperature and precipitation trends.
#
# __Data:__
# The dataset contains daily observations of temperature and precipitation over a month.
#
# ## __Steps to Perform:__
#
# 1. Textual manipulation
# - Convert 'Day' to a string format with appropriate suffixes (1st, 2nd, 3rd, and so on)
# - Classify 'Temperature' into categories (Low, Medium, High) based on predefined thresholds
# - Determine if 'Precipitation' falls under 'Light', 'Moderate', or 'Heavy' rainfall
#
# 2. Iteration and data aggregation
# - Iterate over the DataFrame to calculate weekly averages of temperature and precipitation
# - Summarize findings in a new DataFrame
#
# 3. Sorting
# - Sort the DataFrame by 'Temperature' and 'Precipitation' in ascending and descending order
# - Sort the DataFrame by the day of the month
#
# 4. Plotting
# - Create a line plot for temperature trends
# - Create a bar plot to compare precipitation levels across the month

# %%
# load the data
df = pd.read_csv('/content/regions.csv')
df.head()
# Out:
#    region_id    region_name
# 0        201           Asia
# 1        202         Europe
# 2        203  North America
# 3        204  South America
# 4        205         Africa

# %%
df.shape
# Out:
# (6, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region_id    6 non-null      int64
#  1   region_name  6 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df.nunique()
# Out:
# region_id      6
# region_name    6
# dtype: int64

# %%
df['region_name'] = df['region_name'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region_id    6 non-null      int64
#  1   region_name  6 non-null      category
# dtypes: category(1), int64(1)
# memory usage: 406.0 bytes

# %%
# add 100 to region_id
df.region_id * 2
# Out:
# 0    402
# 1    404
# 2    406
# 3    408
# 4    410
# 5    412
# Name: region_id, dtype: int64

# %%
df
# Out:
#    region_id    region_name
# 0        201           Asia
# 1        202         Europe
# 2        203  North America
# 3        204  South America
# 4        205         Africa
# 5        206        Oceania

# %%
import pandas as pd
import seaborn as sns

# load the data
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# first 5 rwos
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# last 5 rows
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# random 5 rows
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 42        13.94  3.06    Male     No   Sun  Dinner     2
# 50        12.54  2.50    Male     No   Sun  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 5         25.29  4.71    Male     No   Sun  Dinner     4

# %%
# filter all the bills greater than $20
df[df.total_bill > 20]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [97 rows x 7 columns]

# %%
# Filter only the bill of Weekends
df[(df.day == 'Sun') or (df.day ==  'Sat')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7114/4131379930.py in <cell line: 0>()
#       1 # Filter only the bill of Weekends
# ----> 2 df[(df.day == 'Sun') or (df.day ==  'Sat')]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
5 > 10 or 10> 15
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ## Step 1 : Loading the data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/HousePrices.csv')
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# ## Step 1.1 : Data Inspection

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
# number of elements
df.size
# Out:
# 82800

# %%
# overall information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# for non-numerical columns
df.describe(include='object')
# Out:
#                        date                 street     city  statezip country
# count                  4600                   4600     4600      4600    4600
# unique                   70                   4525       44        77       1
# top     2014-06-23 00:00:00  2520 Mulberry Walk NE  Seattle  WA 98103     USA
# freq                    142                      4     1573       148    4600

# %% [markdown]
# **Observations**
#
# 1. There are 18 columns and 4600 rows in the dataset.
# 2. All the columns are completely filled -> No null data.
# 3. There is a requirement of data type conversion for date, city columns.
# 4. The dataset consists of data only from 'USA' and is spread across 44 cities.

# %% [markdown]
# ### Observations from Data Inspection
#
# 1.  **Dataset Dimensions**: The dataset contains `4600` entries (rows) and `18` columns.
# 2.  **Missing Values**: There are no missing values in any of the columns, as indicated by the `Non-Null Count` matching the total `RangeIndex` of 4600 for all columns.
# 3.  **Data Types**: The dataset includes a mix of data types:
#     *   `float64`: `price`, `bedrooms`, `bathrooms`, `floors`
#     *   `int64`: `sqft_living`, `sqft_lot`, `waterfront`, `view`, `condition`, `sqft_above`, `sqft_basement`, `yr_built`, `yr_renovated`
#     *   `object`: `date`, `street`, `city`, `statezip`, `country`
# 4.  **Date Column**: The `date` column is currently of `object` type and should be converted to a datetime object for time-series analysis.
# 5.  **Categorical Columns**: `street`, `city`, `statezip`, and `country` are object type columns. The `country` column has only one unique value ('USA'), indicating it might not be useful for analysis or could be dropped. `city` and `statezip` have multiple unique values.
# 6.  **Numerical Statistics**: `df.describe()` provides summary statistics for numerical columns, showing ranges, means, standard deviations, and quartiles.
# 7.  **Price Range**: The `price` column has a minimum value of `0.0`, which might indicate data entry errors or specific scenarios that need investigation.

# %% [markdown]
# ## Step 2 : Data Preprocessing / Data Cleaning

# %% [markdown]
# ### Table of Contents: Data Cleaning
#
# 1.  **Handling Missing Data**
#     *   Learn techniques to detect, filter, and fill missing values.
#     *   Use `isna` and `notna` for detection.
#     *   Apply `dropna` to remove incomplete rows/columns.
#     *   Use `fillna` for imputation with constants, mean, or interpolation.
#
# 2.  **Data Transformation**
#     *   Perform transformations to clean and reshape datasets.
#     *   Remove duplicates with `drop_duplicates`.
#     *   Apply mapping functions with `map`.
#     *   Replace sentinel values using `replace`.
#     *   Rename indexes and columns with `rename`.
#     *   Discretize continuous data using `cut` and `qcut`.
#     *   Detect and filter outliers.
#     *   Randomly permute or sample data.
#     *   Create dummy variables with `get_dummies`.
#
# 3.  **Extension Data Types**
#     *   Use pandas extension types for better handling of missing values and efficiency.
#     *   Nullable integer, float, and boolean types.
#     *   `StringDtype` for efficient text storage.
#     *   `CategoricalDtype` for repeated values.
#     *   `DatetimeTZDtype` for time zones.
#
# 4.  **String Manipulation**
#     *   Clean and process textual data using Python and pandas string methods.
#     *   Split, strip, join, and replace substrings.
#     *   Apply regex for pattern matching.
#     *   Use `Series.str` methods for vectorized string operations.
#     *   Extract substrings and apply transformations.
#
# 5.  **Categorical Data**
#     *   Optimize performance and memory with categorical encoding.
#     *   Understand categories and codes.
#     *   Convert columns to categorical type.
#     *   Perform computations with ordered categories.
#     *   Use categorical methods like `set_categories` and `remove_unused_categories`.
#
# 6.  **Conclusion**
#     *   Summarizes the importance of cleaning and preparing data before analysis.
#     *   Reinforces that preparation is often 80% of analysis work.
#     *   Highlights pandas tools for efficient workflows.

# %% [markdown]
# ### 1. Handling Missing Data

# %%
# Check for missing values in the current DataFrame (HousePrices.csv)
print("Missing values in HousePrices DataFrame:\n", df.isnull().sum())
# Out:
# Missing values in HousePrices DataFrame:
#  date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# As observed, the `HousePrices.csv` dataset does not have any missing values. To demonstrate techniques for handling missing data, we will load the `titanic` dataset, which contains missing values, into a new DataFrame called `df_missing`.

# %% [markdown]
# ### 2. Data Transformation

# %%
# 2.2.1 check for duplicates
df.duplicated().sum(axis = 0)
# Out:
# np.int64(0)

# %% [markdown]
# ### Since there are no duplicates, we can proceed ahead

# %%
# Apply mapping functions with map
# if house is built before 2000: Old
# else map it as New
df['built'] = df['yr_built'].map(lambda x: 'Old' if x < 2000 else 'New')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'yr_built'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7114/2260302218.py in <cell line: 0>()
#       2 # if house is built before 2000: Old
# ...

# %%
# filter for new
df[df.built == 'New']
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 22    2014-05-02 00:00:00  626000.000000       3.0       2.25         1750
# 31    2014-05-02 00:00:00  499950.000000       4.0       2.50         2860
# 33    2014-05-02 00:00:00  625000.000000       4.0       2.50         2820
# 48    2014-05-02 00:00:00  445700.000000       3.0       2.50         1270
# 49    2014-05-02 00:00:00  838000.000000       4.0       2.50         3310
# ...                   ...            ...       ...        ...          ...
# 4573  2014-07-02 00:00:00  584000.000000       3.0       1.75         1490
# 4575  2014-07-02 00:00:00       0.000000       5.0       6.25         8020
# 4586  2014-07-07 00:00:00  430277.777778       3.0       2.25         1620
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# filter an anomaly
df[df.yr_built < df.yr_renovated]
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  313000.000000       3.0       1.50         1340
# 4     2014-05-02 00:00:00  550000.000000       4.0       2.50         1940
# 5     2014-05-02 00:00:00  490000.000000       2.0       1.00          880
# 9     2014-05-02 00:00:00  640000.000000       4.0       2.00         1520
# 10    2014-05-02 00:00:00  463000.000000       3.0       1.75         1710
# ...                   ...            ...       ...        ...          ...
# 4583  2014-07-07 00:00:00  282766.666667       4.0       2.00         1700
# 4587  2014-07-08 00:00:00  229629.500000       2.0       1.00          770
# 4589  2014-07-08 00:00:00  182805.000000       3.0       1.00         1040
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
## Data Transformations

# convert date column to datetime
df.date = pd.to_datetime(df.date, errors = 'coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   datetime64[ns]
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   category
#  16  statezip       4600 non-null   object
# ...

# %%
df.date.dt.day
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 4595     9
# 4596     9
# 4597     9
# 4598    10
# 4599    10
# Name: date, Length: 4600, dtype: int32

# %%
# Transformation of 'city' column to categorical:
df.city = df.city.astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   datetime64[ns]
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   category
#  16  statezip       4600 non-null   object
# ...

# %% [markdown]
# # Problem 1: Luxury Property Identification
#
# A real estate company wants to identify premium properties for a luxury marketing campaign.
#
# ### Tasks
# 1. Find all houses with a SalePrice greater than the average SalePrice.
# 2. Display:
#    - SalePrice
#    - City
#    - Bedrooms
# 3. Sort the results by SalePrice in descending order.
#
# ### Business Question
# Which properties should be marketed as luxury homes?

# %%
# task 1 : average sale price filter
avg_sale_price = df.price.mean()
luxury_df  = df[df.price > avg_sale_price]
luxury_df.head()
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1  2014-05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 9  2014-05-02   640000.0       4.0       2.00         1520      6200     1.5
# 11 2014-05-02  1400000.0       4.0       2.50         2920      4000     1.5
# 12 2014-05-02   588500.0       3.0       1.75         2330     14892     1.0
# 14 2014-05-02  1200000.0       5.0       2.75         2910      9480     1.5
#
#     waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 1            0     4          5        3370            280      1921
# 9            0     0          3        1520              0      1945
# 11           0     0          5        1910           1010      1909
# 12           0     0          3        1970            360      1980
# 14           0     0          3        2910              0      1939
#
#     yr_renovated                 street       city  statezip country
# ...

# %%
luxury_df[['price', 'city', 'bedrooms']]
# Out:
#              price           city  bedrooms
# 1     2.384000e+06        Seattle       5.0
# 9     6.400000e+05        Seattle       4.0
# 11    1.400000e+06        Seattle       4.0
# 12    5.885000e+05      Sammamish       3.0
# 14    1.200000e+06        Seattle       5.0
# ...            ...            ...       ...
# 4565  6.734768e+05      Sammamish       4.0
# 4566  5.586538e+05        Seattle       3.0
# 4572  1.288333e+06        Seattle       6.0
# 4573  5.840000e+05        Seattle       3.0
# 4578  6.725000e+05  Mercer Island       4.0
#
# [1675 rows x 3 columns]

# %%
# task 3 : sort it
luxury_df.sort_values(by = 'price', ascending = False)
# Out:
#            date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4350 2014-07-03  26590000.0       3.0       2.00         1180      7793
# 4346 2014-06-23  12899000.0       3.0       2.50         2190     11394
# 2286 2014-06-11   7062500.0       5.0       4.50        10040     37325
# 2654 2014-06-17   4668000.0       5.0       6.75         9640     13068
# 2761 2014-06-18   4489000.0       4.0       3.00         6430     27517
# ...         ...         ...       ...        ...          ...       ...
# 65   2014-05-03    553000.0       2.0       1.00          900      5000
# 3874 2014-07-02    552000.0       3.0       2.50         1840      9900
# 1278 2014-05-23    552000.0       3.0       1.00         1430      5000
# 2587 2014-06-16    552000.0       3.0       1.00         1120      2300
# 2103 2014-06-09    552000.0       2.0       2.50         1380       951
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
avg_sale_price
# Out:
# np.float64(551962.9884732141)

# %% [markdown]
# # Problem 2: Best Neighborhoods for Investment
#
# A property investor wants to identify neighborhoods with the highest average property prices.
#
# ### Tasks
# 1. Group the dataset by Neighborhood.
# 2. Calculate the average SalePrice for each neighborhood.
# 3. Display the Top 10 neighborhoods by average SalePrice.
#
# ### Business Question
# Which neighborhoods provide the best investment opportunities?

# %%
# groupby
df.groupby('city').condition.mean().head(10).sort_values(ascending = False)
# Out:
# /tmp/ipykernel_7114/2393152825.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city').condition.mean().head(10).sort_values(ascending = False)
# city
# Beaux Arts Village    4.000000
# Covington             3.651163
# Bellevue              3.590909
# Burien                3.554054
# Clyde Hill            3.545455
# Auburn                3.409091
# Black Diamond         3.222222
# Algona                3.200000
# Bothell               3.151515
# Carnation             3.090909
# Name: condition, dtype: float64

# %% [markdown]
# # Problem 3: Missing Data Investigation
#
# Before building a predictive model, the data team wants to understand the quality of the dataset.
#
# ### Tasks
# 1. Calculate the number of missing values in each column.
# 2. Display only columns having more than 20% missing values.
# 3. Sort the results by missing value count.
#
# ### Business Question
# Which columns require the most data cleaning effort?

# %% [markdown]
# # Problem 4: Large Family Home Analysis
#
# A builder wants to understand characteristics of large family homes.
#
# ### Tasks
# Find houses that satisfy:
# - 4 or more bedrooms
# - 2 or more bathrooms
# - SalePrice above the median SalePrice
#
# Display relevant columns for analysis.
#
# ### Business Question
# What characteristics define high-value family homes?

# %% [markdown]
# # Problem 5: Price Per Square Foot Analysis
#
# Raw sale prices can be misleading when comparing houses of different sizes.
#
# ### Tasks
# 1. Create a new column called `Price_Per_SqFt`.
# 2. Calculate:
#
#    SalePrice / GrLivArea
#
# 3. Display the Top 15 properties based on Price_Per_SqFt.
#
# ### Business Question
# Which houses are most expensive relative to their living area?

# %%
import pandas as pd

df1 = pd.DataFrame({'Category': ['A', 'B', 'A', 'C', 'B', 'A']})
dummy_variables = pd.get_dummies(df1['Category'], prefix='is')
print(dummy_variables)
# Out:
#     is_A   is_B   is_C
# 0   True  False  False
# 1  False   True  False
# 2   True  False  False
# 3  False  False   True
# 4  False   True  False
# 5   True  False  False

# %%
import pandas as pd

df2 = pd.DataFrame({'Category': ['A', 'B', 'A', 'C', 'B', 'A']})
df2['Category_LabelEncoded'] = df2['Category'].astype('category').cat.codes
print(df2[['Category', 'Category_LabelEncoded']])
# Out:
#   Category  Category_LabelEncoded
# 0        A                      0
# 1        B                      1
# 2        A                      0
# 3        C                      2
# 4        B                      1
# 5        A                      0

# %%
# create a dataframe with 3 columns and 20 rows
df = pd.DataFrame({'A': np.random.randint(0, 10, 20),
                   'B': np.random.randint(0,20, 20),
                   'C': np.random.randint(0, 100, 20)})
df.head()
# Out:
#    A   B   C
# 0  5  13  64
# 1  0  14   3
# 2  7   4  51
# 3  4  18  64
# 4  7   7   0

# %%
# iterate over this df with iterrows()
for index, row in df.iterrows():
    print(f"{index} row : Col0 : ", row.A, row.index)
    print(f"{index} row : Col1 : ", row.B)
    print(f"{index} row : Col2 : ", row.C)
# Out:
# 0 row : Col0 :  5 Index(['A', 'B', 'C'], dtype='object')
# 0 row : Col1 :  13
# 0 row : Col2 :  64
# 1 row : Col0 :  0 Index(['A', 'B', 'C'], dtype='object')
# 1 row : Col1 :  14
# 1 row : Col2 :  3
# 2 row : Col0 :  7 Index(['A', 'B', 'C'], dtype='object')
# 2 row : Col1 :  4
# 2 row : Col2 :  51
# 3 row : Col0 :  4 Index(['A', 'B', 'C'], dtype='object')
# 3 row : Col1 :  18
# 3 row : Col2 :  64
# 4 row : Col0 :  7 Index(['A', 'B', 'C'], dtype='object')
# 4 row : Col1 :  7
# 4 row : Col2 :  0
# 5 row : Col0 :  4 Index(['A', 'B', 'C'], dtype='object')
# 5 row : Col1 :  19
# 5 row : Col2 :  87
# 6 row : Col0 :  9 Index(['A', 'B', 'C'], dtype='object')
# 6 row : Col1 :  8
# 6 row : Col2 :  96
# 7 row : Col0 :  8 Index(['A', 'B', 'C'], dtype='object')
# 7 row : Col1 :  7
# 7 row : Col2 :  45
# 8 row : Col0 :  2 Index(['A', 'B', 'C'], dtype='object')
# 8 row : Col1 :  12
# 8 row : Col2 :  78
# 9 row : Col0 :  7 Index(['A', 'B', 'C'], dtype='object')
# 9 row : Col1 :  6
# ...

# %%
# index loc
df.iloc[0:5,0]
# Out:
# 0    5
# 1    0
# 2    7
# 3    4
# 4    7
# Name: A, dtype: int64

# %%
# loc
df.loc[0:5,"B"]
# Out:
# 0    13
# 1    14
# 2     4
# 3    18
# 4     7
# 5    19
# Name: B, dtype: int64

# %%
# plot
df.A.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
import sqlite3
