# %%
# now pofoms add twise additional 
import numpy as np

a = np.array([1,2,3,4])

# %%
arr_3D = np.array(2)

print(arr_3D)
# Out:
# 2

# %%
# Create a one-dimensional NumPy array containing at least ten elements
arr_1D = np.arange(1,100)
print(arr_1D[-1:-10])
# Out:
# []
